# %% [markdown]
# # Proyek Analisis Data: E-Commerce Public Dataset
# - **Nama:** Raafi Kurnia Desita
# - **Email:** raafikurnia02@gmail.com
# - **ID Dicoding:** raafikurnia

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana performa penjualan  e-commerce selama beberpa bulan terakhir?
# - Produk apa yang memiliki tingkat penjualan tertinggi dan terendah?
# -  Kota mana yang memiliki jumlah pelanggan terbanyak?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt
    import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# *   Tabel Customers

# %%
customers_df = pd.read_csv("https://raw.githubusercontent.com/Raafikurnia/proyek-dicoding-analisis-data-dengan-python/main/E-Commerce%20Public%20Dataset/customers_dataset.csv")
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# *   Tabel orders

# %%
orders_df = pd.read_csv("https://raw.githubusercontent.com/Raafikurnia/proyek-dicoding-analisis-data-dengan-python/main/E-Commerce%20Public%20Dataset/orders_dataset.csv")
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
order_payment_df = pd.read_csv("https://raw.githubusercontent.com/Raafikurnia/proyek-dicoding-analisis-data-dengan-python/main/E-Commerce%20Public%20Dataset/order_payments_dataset.csv")
order_payment_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %% [markdown]
# *   Tabel product

# %%
product_df = pd.read_csv("https://raw.githubusercontent.com/Raafikurnia/proyek-dicoding-analisis-data-dengan-python/main/E-Commerce%20Public%20Dataset/products_dataset.csv")
product_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
product_category_df = pd.read_csv("https://raw.githubusercontent.com/Raafikurnia/proyek-dicoding-analisis-data-dengan-python/main/E-Commerce%20Public%20Dataset/product_category_name_translation.csv")
product_category_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# *   Tabel order_items_dataset

# %%
order_items_dataset_df = pd.read_csv("https://raw.githubusercontent.com/Raafikurnia/proyek-dicoding-analisis-data-dengan-python/main/E-Commerce%20Public%20Dataset/order_items_dataset.csv")
order_items_dataset_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# *   Menilai data customers_df

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
customers_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
customers_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# *   Menilai data orders_df

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
print("Jumlah duplikasi: ",orders_df.duplicated().sum())
orders_df.describe()
# Out:
# Jumlah duplikasi:  0
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %%
orders_df.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %% [markdown]
# *   Menilai data product_df

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
product_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
print("Jumlah duplikasi: ", product_df.duplicated().sum())
product_df.describe()
# Out:
# Jumlah duplikasi:  0
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %%
product_df.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %%
product_category_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
print("Jumlah duplikasi: ", product_category_df.duplicated().sum())
product_category_df.describe()
# Out:
# Jumlah duplikasi:  0
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %% [markdown]
# *   Menilai order_items_dataset

# %%
order_items_dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
print("Jumlah duplikasi: ", order_items_dataset_df.duplicated().sum())
order_items_dataset_df.describe()
# Out:
# Jumlah duplikasi:  0
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# *   Membersihkan data customers_df

# %% [markdown]
#        Data customers sudah bersih. Tidak ada kesalahan tipe data, missing value, duplicate data, maupun inacurate data

# %% [markdown]
# *   Membersihkan data order_df

# %% [markdown]
# 1.   Menangani kesalahan tipe data

# %%
datetime_columns = ["order_purchase_timestamp", "order_approved_at", "order_delivered_carrier_date", "order_delivered_customer_date", "order_estimated_delivery_date"]

for column in datetime_columns:
  orders_df[column] = pd.to_datetime(orders_df[column])

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %% [markdown]
# 2.   Menangani missing value

# %%
orders_df[orders_df.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %%
orders_df.order_approved_at.value_counts()
# Out:
# 2018-02-27 04:31:10    9
# 2017-11-07 07:30:38    7
# 2018-02-27 04:31:01    7
# 2018-02-06 05:31:52    7
# 2017-11-07 07:30:29    7
#                       ..
# 2018-08-22 11:50:14    1
# 2017-09-22 11:27:36    1
# 2018-03-07 16:40:32    1
# 2017-08-08 10:50:15    1
# 2018-03-09 11:20:28    1
# Name: order_approved_at, Length: 90733, dtype: int64

# %%
orders_df.fillna(value="2018-02-27 04:31:10", inplace=True)

# %%
orders_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# *   Membersihkan data product_df

# %% [markdown]
# 1.   Menangani missing value

# %%
product_df[product_df.product_category_name.isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %%
product_df.product_category_name.value_counts()
# Out:
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: product_category_name, Length: 73, dtype: int64

# %%
product_df.product_category_name.fillna(value="cama_mesa_banho", inplace=True)

# %%
product_df.isna().sum()
# Out:
# product_id                      0
# product_category_name           0
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
product_df.product_name_lenght.value_counts()
# Out:
# 60.0    2182
# 59.0    2025
# 58.0    1887
# 57.0    1719
# 55.0    1683
#         ...
# 66.0       1
# 72.0       1
# 67.0       1
# 76.0       1
# 6.0        1
# Name: product_name_lenght, Length: 66, dtype: int64

# %%
product_df.product_name_lenght.fillna(value="60.0", inplace=True)

# %%
product_df.product_description_lenght.value_counts()
# Out:
# 404.0     94
# 729.0     86
# 651.0     66
# 703.0     66
# 236.0     65
#           ..
# 2795.0     1
# 2308.0     1
# 3698.0     1
# 3522.0     1
# 2207.0     1
# Name: product_description_lenght, Length: 2960, dtype: int64

# %%
product_df.product_description_lenght.fillna(value="404.0", inplace=True)

# %%
product_df.product_photos_qty.value_counts()
# Out:
# 1.0     16489
# 2.0      6263
# 3.0      3860
# 4.0      2428
# 5.0      1484
# 6.0       968
# 7.0       343
# 8.0       192
# 9.0       105
# 10.0       95
# 11.0       46
# 12.0       35
# 13.0        9
# 15.0        8
# 17.0        7
# 14.0        5
# 18.0        2
# 20.0        1
# 19.0        1
# Name: product_photos_qty, dtype: int64

# %%
product_df.product_photos_qty.fillna(value="1.0", inplace=True)

# %%
product_df.product_weight_g.value_counts()
# Out:
# 200.0     2084
# 300.0     1561
# 150.0     1259
# 400.0     1206
# 100.0     1188
#           ...
# 6075.0       1
# 822.0        1
# 631.0        1
# 2925.0       1
# 1920.0       1
# Name: product_weight_g, Length: 2204, dtype: int64

# %%
product_df.product_weight_g.fillna(value="200.0", inplace=True)

# %%
product_df.product_length_cm.value_counts()
# Out:
# 16.0    5520
# 20.0    2816
# 30.0    2029
# 18.0    1502
# 25.0    1387
#         ...
# 96.0       4
# 10.0       3
# 8.0        2
# 9.0        2
# 7.0        1
# Name: product_length_cm, Length: 99, dtype: int64

# %%
product_df.product_length_cm.fillna(value="16.0", inplace=True)

# %%
product_df.product_height_cm.value_counts()
# Out:
# 10.0    2548
# 15.0    2022
# 20.0    1991
# 16.0    1595
# 11.0    1551
#         ...
# 98.0       2
# 97.0       2
# 99.0       1
# 89.0       1
# 94.0       1
# Name: product_height_cm, Length: 102, dtype: int64

# %%
product_df.product_height_cm.fillna(value="10.0", inplace=True)

# %%
product_df.product_width_cm.value_counts()
# Out:
# 11.0     3718
# 20.0     3053
# 16.0     2808
# 15.0     2393
# 30.0     1786
#          ...
# 103.0       1
# 86.0        1
# 98.0        1
# 87.0        1
# 104.0       1
# Name: product_width_cm, Length: 95, dtype: int64

# %%
product_df.product_width_cm.fillna(value="11.0", inplace=True)

# %%
orders_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# *   Menilai data order_items_dataset

# %% [markdown]
#        Data order_items_dataset sudah bersih. Tidak ada kesalahan tipe data, missing value, duplicate data, maupun inacurate data

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explor data customers

# %%
customers_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %% [markdown]
# Dari eksplorasi tersebut, kita dapat memperoleh informasi berupa total customer e-commerce yang berjumlah 99441 orang.

# %%
customers_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %% [markdown]
# Dari eksplorasi tersebut, kita dapat memperoleh informasi bahwa sao paulo merupakan kota yang memiliki custommer terbanyak, yaitu sejumlah 15540 customers

# %% [markdown]
# ### Explor data order

# %%
orders_df.describe(include="all")
# Out:
# <ipython-input-51-903538279252>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   orders_df.describe(include="all")
# <ipython-input-51-903538279252>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   orders_df.describe(include="all")
# <ipython-input-51-903538279252>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   orders_df.describe(include="all")
# ...

# %%
orders_df.groupby(by="order_purchase_timestamp").order_id.nunique().sort_values(ascending=False)
# Out:
# order_purchase_timestamp
# 2018-06-01 13:39:44    3
# 2018-07-28 13:11:22    3
# 2018-04-11 10:48:14    3
# 2018-08-02 12:06:09    3
# 2018-08-02 12:06:07    3
#                       ..
# 2017-11-07 22:02:05    1
# 2017-11-07 21:58:38    1
# 2017-11-07 21:57:26    1
# 2017-11-07 21:50:08    1
# 2018-10-17 17:30:18    1
# Name: order_id, Length: 98875, dtype: int64

# %%
delivery_time = orders_df["order_delivered_customer_date"] - orders_df["order_purchase_timestamp"]
delivery_time = delivery_time.apply(lambda x: x.total_seconds())
orders_df["delivery_time"] = round(delivery_time/86400)

# %%
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders_df.describe(include="all")
# Out:
# <ipython-input-55-903538279252>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   orders_df.describe(include="all")
# <ipython-input-55-903538279252>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   orders_df.describe(include="all")
# <ipython-input-55-903538279252>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   orders_df.describe(include="all")
# ...

# %% [markdown]
# Dari data tersebeut diketahui bahwa rata rata waktu yang diperlukan untuk pesanan bisa sampai ke tangan customers adalah 15 hari setelah pesanan dibuat

# %% [markdown]
# ### Explor data orders dan customers

# %%
    customer_id_in_orders_df =  orders_df.customer_id.tolist()
    customers_df["status"] = customers_df["customer_id"].apply(lambda x: "Active" if x in customer_id_in_orders_df else "Non Active")
    customers_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 19044  23301bca57eda7af3e47546760d9e869  3e6bc4180ba32d44f8278f211e2231f7
# 19505  afb19a4b667cb708caab312757ec3d3f  a7e7b19ff34ab885f7b7331de2417cf3
# 21965  08d5cabc983964257832805dc6f0e74e  584bb2bc20695e10db1ddc15d027b8b4
# 85350  38db66ceeb2f79538b16c2add29879ee  4f4816c14a2f023355f36b4f1433a914
# 61155  ed850b120dcf3049743a2ec2e015ae9f  e3084d5aa230db5c53a1bfd489a738a3
#
#        customer_zip_code_prefix        customer_city customer_state  status
# 19044                     12246  sao jose dos campos             SP  Active
# 19505                     78043               cuiaba             MT  Active
# 21965                     11500              cubatao             SP  Active
# 85350                      2802            sao paulo             SP  Active
# 61155                      1050            sao paulo             SP  Active

# %%
  customers_df.groupby(by="status").customer_id.count()
# Out:
# status
# Active    99441
# Name: customer_id, dtype: int64

# %% [markdown]
# Berdasarkan informasi, dapat diketahui bahwa sebanyak 99441 customers meripakan customer yang active (pernah melakukan order)

# %%
orders_customers_df = pd.merge(
        left=orders_df,
        right=customers_df,
        how="left",
        left_on="customer_id",
        right_on="customer_id"
)
orders_customers_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders_customers_df.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#            customer_city  order_id
# 0              sao paulo     15540
# 1         rio de janeiro      6882
# 2         belo horizonte      2773
# 3               brasilia      2131
# 4               curitiba      1521
# 5               campinas      1444
# 6           porto alegre      1379
# 7               salvador      1245
# 8              guarulhos      1189
# 9  sao bernardo do campo       938

# %% [markdown]
# Dari informasi dapat diketahui bahwa kota Sao Paulo merupakan kota yang memiliki jumlah orderan terbanyak

# %%
orders_customers_df.groupby(by="order_status").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#   order_status  order_id
# 0    delivered     96478
# 1      shipped      1107
# 2     canceled       625
# 3  unavailable       609
# 4     invoiced       314
# 5   processing       301
# 6      created         5
# 7     approved         2

# %% [markdown]
# ### Explor data orders_customers dan order_payment

# %%
order_all_df = pd.merge(
        left=orders_customers_df,
        right=order_payment_df,
        how="left",
        left_on="order_id",
        right_on="order_id"
)
order_all_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# ### Explor data product dan product_category

# %%
product_pc_df = pd.merge(
        left=product_df,
        right=product_category_df,
        how="left",
        left_on="product_category_name",
        right_on="product_category_name"
)
product_pc_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#   product_name_lenght product_description_lenght product_photos_qty  \
# 0                40.0                      287.0                1.0
# 1                44.0                      276.0                1.0
# 2                46.0                      250.0                1.0
# 3                27.0                      261.0                1.0
# 4                37.0                      402.0                4.0
#
#   product_weight_g product_length_cm product_height_cm product_width_cm  \
# 0            225.0              16.0              10.0             14.0
# ...

# %%
product_pc_df.groupby(by="product_category_name").product_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#     product_category_name  product_id
# 0         cama_mesa_banho        3639
# 1           esporte_lazer        2867
# 2        moveis_decoracao        2657
# 3            beleza_saude        2444
# 4   utilidades_domesticas        2335
# 5              automotivo        1900
# 6  informatica_acessorios        1639
# 7              brinquedos        1411
# 8      relogios_presentes        1329
# 9               telefonia        1134

# %% [markdown]
# ### Explor data order_items_dataset dan product_product_category

# %%
dataorder_df = pd.merge(
        left=order_items_dataset_df,
        right=product_pc_df,
        how="left",
        left_on="product_id",
        right_on="product_id"
)
dataorder_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value product_category_name  \
# 0  2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1  2017-05-03 11:05:13  239.90          19.93              pet_shop
# ...

# %% [markdown]
# ### Explor data all_df

# %%
all_df = pd.merge(
        left=order_all_df,
        right=dataorder_df,
        how="left",
        left_on="order_id",
        right_on="order_id"
)
all_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118434 entries, 0 to 118433
# Data columns (total 33 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       118434 non-null  object
#  1   customer_id                    118434 non-null  object
#  2   order_status                   118434 non-null  object
#  3   order_purchase_timestamp       118434 non-null  datetime64[ns]
#  4   order_approved_at              118434 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   118434 non-null  datetime64[ns]
#  6   order_delivered_customer_date  118434 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  118434 non-null  datetime64[ns]
#  8   delivery_time                  118434 non-null  float64
#  9   customer_unique_id             118434 non-null  object
#  10  customer_zip_code_prefix       118434 non-null  int64
# ...

# %% [markdown]
# Download all_df

# %%
all_df.to_csv("all_data.csv", index=False)

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### - Bagaimana performa penjualan e-commerce selama beberpa bulan terakhir?

# %%
monthly_orders_df = all_df.resample(rule='M', on='order_approved_at').agg({
        "order_id": "nunique",
        "price": "sum"
})
monthly_orders_df.index = monthly_orders_df.index.strftime('%B') #mengubah format order date menjadi nama bulan

monthly_orders_df = monthly_orders_df.reset_index()
monthly_orders_df.rename(columns={
        "order_id": "order_count",
        "price": "revenue"
}, inplace=True)

monthly_orders_df.head()
# Out:
#   order_approved_at  order_count    revenue
# 0         September            1     134.97
# 1           October          320   51074.62
# 2          November            0       0.00
# 3          December            1      10.90
# 4           January          760  123055.93

# %%
monthly_orders_df.sort_values(by='order_count')
# Out:
#    order_approved_at  order_count     revenue
# 2           November            0        0.00
# 0          September            1      134.97
# 3           December            1       10.90
# 24         September            1      145.00
# 1            October          320    51074.62
# 4            January          760   123055.93
# 5           February         1765   261021.82
# 7              April         2374   389495.92
# 6              March         2689   392718.30
# 9               June         3252   457208.99
# 8                May         3693   546437.40
# 10              July         3974   528051.93
# 12         September         4301   651927.77
# 11            August         4348   600708.01
# 13           October         4590   700376.60
# 15          December         5832   792906.15
# 21              June         6164   913617.03
# 22              July         6176   906294.24
# 23            August         6620   909732.17
# ...

# %%
month_mapping={
    "January": 1,
    "February": 2,
    "March": 3,
    "April": 4,
    "May": 5,
    "June": 6,
    "July": 7,
    "August" : 8,
    "September":9,
    "October":10,
    "November": 11,
    "December": 12
}

monthly_orders_df["month_numeric"] = monthly_orders_df["order_approved_at"].map(month_mapping)
monthly_orders_df=monthly_orders_df.sort_values("month_numeric")
monthly_orders_df=monthly_orders_df.drop("month_numeric", axis=1)

# %%
    plt.figure(figsize=(10, 5))
    plt.plot(monthly_orders_df["order_approved_at"], monthly_orders_df["order_count"], marker='o', linewidth=2, color="#72BCD4")
    plt.title("Number of Orders per Month", loc="center", fontsize=20)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)
    plt.show()

# %% [markdown]
# ### Produk apa yang memiliki tingkat penjualan tertinggi dan terendah?

# %%
sum_order_items_df = all_df.groupby("product_category_name_english")["product_id"].count().reset_index()
sum_order_items_df = sum_order_items_df.sort_values(by="product_id", ascending=False)
sum_order_items_df.head(15)
# Out:
#    product_category_name_english  product_id
# 7                 bed_bath_table       13521
# 43                 health_beauty        9975
# 65                sports_leisure        8945
# 39               furniture_decor        8744
# 15         computers_accessories        8082
# 49                    housewares        7355
# 70                 watches_gifts        6201
# 68                     telephony        4721
# 42                  garden_tools        4574
# 5                           auto        4379
# 69                          toys        4273
# 20                    cool_stuff        3987
# 59                     perfumery        3560
# 6                           baby        3196
# 26                   electronics        2845

# %%
ig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="product_id", y="product_category_name_english", data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best Performing Product", loc="center", fontsize=15)
ax[0].tick_params(axis ='y', labelsize=12)

sns.barplot(x="product_id", y="product_category_name_english", data=sum_order_items_df.sort_values(by="product_id", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Worst Performing Product", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)

plt.suptitle("Best and Worst Performing Product by Number of Sales", fontsize=20)
plt.show()
# Out:
# <ipython-input-73-e6b3455587bb>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="product_id", y="product_category_name_english", data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
# <ipython-input-73-e6b3455587bb>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="product_id", y="product_category_name_english", data=sum_order_items_df.sort_values(by="product_id", ascending=True).head(5), palette=colors, ax=ax[1])

# %% [markdown]
# ### Kota mana yang memiliki jumlah pelanggan terbanyak?

# %%
bystate_df = all_df.groupby(by="customer_state").customer_id.nunique().reset_index()
bystate_df.rename(columns={
        "customer_id": "customer_count"
}, inplace=True)
bystate_df
plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
sns.barplot(
        x="customer_count",
        y="customer_state",
        data=bystate_df.sort_values(by="customer_count", ascending=False),
        palette=colors_
)
plt.title("Number of Customer by States", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()
# Out:
# <ipython-input-79-80d5c715627a>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# <ipython-input-79-80d5c715627a>:8: UserWarning:
# The palette list has fewer values (8) than needed (27) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(

# %%
bycity_df = all_df.groupby(by="customer_city").customer_id.nunique().reset_index()
bycity_df.rename(columns={
        "customer_id": "customer_count"
}, inplace=True)
bycity_df
plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
sns.barplot(
        x="customer_count",
        y="customer_city",
        data=bycity_df.sort_values(by="customer_count", ascending=False).head(5),
        palette=colors_
)
plt.title("Number of Customer by City", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()
# Out:
# <ipython-input-81-471ade7bf72e>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# <ipython-input-81-471ade7bf72e>:8: UserWarning: The palette list has more values (8) than needed (5), which may not be intended.
#   sns.barplot(

# %%
city_df = all_df.groupby(by="customer_city").size().reset_index(name="count").sort_values(by="count", ascending=False).head(5)

plt.figure(figsize=(10, 5))
most_common_city = city_df.loc[city_df['count'].idxmax(), 'customer_city']

sns.barplot(x="customer_city",
            y="count",
            data=city_df,
            palette=["#72BCD4" if city == most_common_city else "#D3D3D3" for city in city_df['customer_city']]
            )
plt.title("Total Customer by City", loc="center", fontsize=15)
plt.ylabel("Total Customers")
plt.xlabel("City")
plt.xticks(rotation=0)
plt.show()
# Out:
# <ipython-input-82-2c060ec25193>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="customer_city",

# %% [markdown]
# ## Conclusion

# %% [markdown]
# 1. Performa e-commeerce mengalami kenaikan dan penurunan. Perfoma terbaik jatuh pada bulan Agustus
# 2. Produk yang memliki tingkat penjualan tertinggi adalah bed_bath_table. Sedangkan produk yang memiliki tingkat peenjualan terendah adalah security_and_service
# 3. Kota yang memiliki jumlah customers terbanyak adalah kota Sao paulo.
